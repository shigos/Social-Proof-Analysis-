# %%
import matplotlib.pyplot as plt

# %%
verified_title={
    'great product': 87,
 'great': 54,
 'love it': 33,
 'good': 32,
 'excellent': 28,
 'good product': 25,
 'love it!': 21,
 'awesome': 20,
 'yummy': 20,
 'works great': 20,
 'great movie': 19,
 'great hairspray': 16,
 'the best': 15,
 'delicious': 15,
 'great hold': 15,
 'great product!': 12,
 'yum': 11,
 'nice': 11,
 'easy to use': 11,
 'excellent product': 10,
 'wonderful': 9,
 'great!': 9,
 'works great!': 9,
 'pantene pro-v airspray': 9}
verified=[]
for k, v in verified_title.items():
    verified.append(k)


import numpy as np
fig, ax = plt.subplots(figsize = (10,4))

keys = verified_title.keys()
vals = verified_title.values()

plt.bar(keys,list(vals),label= 'Real distribution')


ax.set_ylabel('Times Appeared')
ax.set_xlabel('Titles')

ax.set_xticklabels(list(keys),rotation = 90)
ax.legend (bbox_to_anchor=(1, 1), loc="upper right", borderaxespad=0.)

plt.show
#verified review titles positive
# Out:
# <ipython-input-84-efd4502bf19d>:43: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(list(keys),rotation = 90)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
unverified_title = {
'great product': 768,
 'clorox wipes': 388,
 'great': 227,
 'love it': 226,
 'great product!': 196,
 'love it!': 175,
 'awesome': 172,
 'clorox': 119,
 'easy to use': 117,
 'olay total effects': 117,
 'wipes': 116,
 'good product': 115,
 'awesome product': 112,
 'love this product': 106,
 'excellent': 100,
 'amazing': 99,
 'excellent product': 92,
 'love': 91,
 'good': 82,
 'awesome!': 77,
 'tide pods': 76,
 'great!': 75,
 'love this product!': 72,
 'the best': 68}
unverified=[]
for k, v in verified_title.items():
    verified.append(k)


import numpy as np
fig, ax = plt.subplots(figsize = (10,4))

keys = unverified_title.keys()
vals = unverified_title.values()

plt.bar(keys,list(vals),label= 'Real distribution')


ax.set_ylabel('Times Appeared')
ax.set_xlabel('Titles')

ax.set_xticklabels(list(keys),rotation = 90)
ax.legend (bbox_to_anchor=(1, 1), loc="upper right", borderaxespad=0.)

plt.show

# unverified review title positive
# Out:
# <ipython-input-85-7e78b0a9102f>:43: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(list(keys),rotation = 90)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
similar = []
for i in unverified_title:
    if i in verified_title:
        similar.append(i)
similar   # number of titles that appear in both verified and unverified
# Out:
# ['great product',
#  'great',
#  'love it',
#  'great product!',
#  'love it!',
#  'awesome',
#  'easy to use',
#  'good product',
#  'excellent',
#  'excellent product',
#  'good',
#  'great!',
#  'the best']

# %%
similar = []
for i in unverified_title:
    if i in verified_title:
        similar.append(i)
similar
# Out:
# ['great product',
#  'great',
#  'love it',
#  'great product!',
#  'love it!',
#  'awesome',
#  'easy to use',
#  'good product',
#  'excellent',
#  'excellent product',
#  'good',
#  'great!',
#  'the best']

# %%
len(similar)
# Out:
# 13

# %%
similar = []
for i in unverified_title:
    if i in verified_title:
        similar.append(i)
similar
# Out:
# ['great product',
#  'great',
#  'love it',
#  'great product!',
#  'love it!',
#  'awesome',
#  'easy to use',
#  'good product',
#  'excellent',
#  'excellent product',
#  'good',
#  'great!',
#  'the best']

# %%
#verified reviews with low rating

vlr = {'not what i expected': 2,
 'disappointed': 2,
 'not a fan': 2,
 'it has a nasty smell that would get anyone sick': 1,
 "it didn't feel natural on my skin.": 1,
 'different formula than normal': 1,
 'definetaly not a granola bar': 1,
 'i scream when i look into the mirror': 1,
 'nothing to write home about': 1,
 'no quality': 1,
 'basically like the shampoo only thicker.': 1,
 'scammed': 1,
 "didn't get what i ordered": 1,
 'ragu cheesy roasted garlic parmesan sauce': 1,
 'faulty workmanship': 1,
 'bland': 1,
 'tai pei': 1,
 'd con': 1,
 'you send the wrong product': 1,
 'not as advertised': 1,
 'horrible': 1,
 'no no no.': 1,
 "don't buy": 1}
vlrl = []
for k, v in vlr.items():
    vlrl.append(k)
vlrl
# Out:
# ['not what i expected',
#  'disappointed',
#  'not a fan',
#  'it has a nasty smell that would get anyone sick',
#  "it didn't feel natural on my skin.",
#  'different formula than normal',
#  'definetaly not a granola bar',
#  'i scream when i look into the mirror',
#  'nothing to write home about',
#  'no quality',
#  'basically like the shampoo only thicker.',
#  'scammed',
#  "didn't get what i ordered",
#  'ragu cheesy roasted garlic parmesan sauce',
#  'faulty workmanship',
#  'bland',
#  'tai pei',
#  'd con',
#  'you send the wrong product',
#  'not as advertised',
#  'horrible',
#  'no no no.',
#  "don't buy"]

# %%
#unverified reviews with a low rating
unvd={'disappointed': 31,
 'horrible': 23,
 'poor quality': 16,
 'tide pods': 16,
 'terrible': 15,
 'waste of money': 13,
 'very disappointed': 12,
 'new formula': 8,
 'horrible!': 8,
 'not for me': 8,
 'not worth it': 6,
 'what happened': 6,
 'not happy': 6,
 'bring back old formula': 6,
 'ruined clothes': 6,
 'disappointing': 5,
 'new formula is terrible': 5,
 'please bring back the old formula': 5,
 'terrible product': 5,
 'awful': 5,
 'do not buy': 5,
 'pods': 5,
 'reveal mop': 5,
 'reveal spray mop': 5,
 'very disappointing': 4,
 'not what i expected': 4,}
unvdl = []
for k, v in unvd.items():
    unvdl.append(k)
unvdl

import numpy as np
fig, ax = plt.subplots(figsize = (10,4))

keys = unvd.keys()
vals = unvd.values()

plt.bar(keys,list(vals),label= 'Real distribution')


ax.set_ylabel('Times Appeared')
ax.set_xlabel('Titles')

ax.set_xticklabels(list(keys),rotation = 90)
ax.legend (bbox_to_anchor=(1, 1), loc="upper right", borderaxespad=0.)

plt.show
# Out:
# <ipython-input-82-3e68d285e314>:45: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(list(keys),rotation = 90)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
lr = []
for i in unvdl:
    if i in vlrl:
        lr.append(i)
lr
# Out:
# ['disappointed', 'horrible', 'not what i expected']

# %%
# Out:
# <ipython-input-77-763d4767787b>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(list(keys),rotation = 90)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import numpy as np
fig, ax = plt.subplots(figsize = (10,4))

keys = vlr.keys()
vals = vlr.values()

plt.bar(keys,list(vals),label= 'Real distribution')


ax.set_ylabel('Times Appeared')
ax.set_xlabel('Titles')

ax.set_xticklabels(list(keys),rotation = 90)
ax.legend (bbox_to_anchor=(1, 1), loc="upper right", borderaxespad=0.)

plt.show
# Out:
# <ipython-input-81-d2b90a47e55a>:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(list(keys),rotation = 90)
# <function matplotlib.pyplot.show(close=None, block=None)>
